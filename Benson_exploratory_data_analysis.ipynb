# %% [markdown]
# ## Download the data

# %%
# %matplotlib inline
import mta
from pprint import pprint
import datetime

# %%
mta.get_turnstile_data(num_files=14,
                       data_url="http://web.mta.info/developers/turnstile.html",
                       destination='./data/')
# Out:
# Downloading turnstile key from http://web.mta.info/developers/resources/nyct/turnstile/Remote-Booth-Station.xls
# Downloading 1 of 14: http://web.mta.info/developers/data/nyct/turnstile/turnstile_141122.txt
# Downloading 2 of 14: http://web.mta.info/developers/data/nyct/turnstile/turnstile_141115.txt
# Downloading 3 of 14: http://web.mta.info/developers/data/nyct/turnstile/turnstile_141108.txt
# Downloading 4 of 14: http://web.mta.info/developers/data/nyct/turnstile/turnstile_141101.txt
# Downloading 5 of 14: http://web.mta.info/developers/data/nyct/turnstile/turnstile_141025.txt
# Downloading 6 of 14: http://web.mta.info/developers/data/nyct/turnstile/turnstile_141018.txt
# Downloading 7 of 14: http://web.mta.info/developers/data/nyct/turnstile/turnstile_141011.txt
# Downloading 8 of 14: http://web.mta.info/developers/data/nyct/turnstile/turnstile_141004.txt
# Downloading 9 of 14: http://web.mta.info/developers/data/nyct/turnstile/turnstile_140927.txt
# Downloading 10 of 14: http://web.mta.info/developers/data/nyct/turnstile/turnstile_140920.txt
# Downloading 11 of 14: http://web.mta.info/developers/data/nyct/turnstile/turnstile_140913.txt
# Downloading 12 of 14: http://web.mta.info/developers/data/nyct/turnstile/turnstile_140906.txt
# Downloading 13 of 14: http://web.mta.info/developers/data/nyct/turnstile/turnstile_140830.txt
# Downloading 14 of 14: http://web.mta.info/developers/data/nyct/turnstile/turnstile_140823.txt
# Done.

# %% [markdown]
# ## Get the data out of the csvs

# %%
filenames = mta.get_glob()
ts = mta.extract_turnstile_data_from_csvs(filenames)
print len(ts)
# Out:
# extracting  data/turnstile_140823.txt
# extracting
#  data/turnstile_140830.txt
# extracting
#  data/turnstile_140906.txt
# extracting
#  data/turnstile_140913.txt
# extracting
#  data/turnstile_140920.txt
# extracting
#  data/turnstile_140927.txt
# extracting
#  data/turnstile_141004.txt
# extracting
#  data/turnstile_141011.txt
# extracting
#  data/turnstile_141018.txt
# extracting
#  data/turnstile_141025.txt
# extracting
#  data/turnstile_141101.txt
# extracting
#  data/turnstile_141108.txt
# extracting
#  data/turnstile_141115.txt
# extracting
#  data/turnstile_141122.txt
# 4571

# %% [markdown]
# ##Get turnstile counts

# %%
# this is actually quite awesome but not at all fast. 
#2014-08-08 17:00:14.194766
#calculating turnstile counts for 4545 turnstiles.
#2014-08-08 17:01:58.087474

turnstile_data = mta.get_ts_counts_fastawesome(ts)
print len(turnstile_data)
# Out:
# calculating turnstile counts for 4571 turnstiles.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-aed0074ca89d> in <module>()
#       6 #2014-08-08 17:01:58.087474
#       7
# ----> 8 turnstile_data = mta.get_ts_counts_fastawesome(ts)
#       9 print len(turnstile_data)
#
# /Users/gabrielgluck/Projects/benson/mta.pyc in get_ts_counts_fastawesome(ts)
#     103     for turnstile,tlist in ts.iteritems():
#     104
# --> 105         tlist = np.array(tlist).reshape(len(tlist)/5,5)
#     106         days = sorted(list(set(tlist[:,0])))
#     107
#
# ValueError: total size of new array must be unchanged

# %% [markdown]
# ##Collapse turnstiles to booth-remotes

# %%
# collapse the data to booth-remotes
#[takes a minute but not as long as the day count extraction]
boothremote_raw,boothremotes = mta.collapse_data_to_booth_remote(turnstile_data)

# %%
# how many boothremotes are there?
print 'number of boothremotes: ',len(boothremotes) 

# what does one boothremote look like?
br_id,br_counts = boothremotes.iteritems().next()
#print 'br id of first booth remote: ',br_id
#print 'daily counts:'
#pprint(br_counts)
# Out:
# number of boothremotes:  729

# %% [markdown]
# #PLOT

# %%
import matplotlib.pyplot as plt
# plot the turnstile entry counts per day for one boothremote
dates,counts = mta.dates_and_counts(br_counts)
f = plt.figure(figsize=(10,3))
p = plt.plot(dates,counts)

# %%
import numpy as np

counts_by_week = mta.reshape_flat_counts_to_weekly(counts)
#print counts_by_week

for week in counts_by_week:
    plt.plot(week)
    
xl = plt.xlabel('Day of the week')
yl = plt.ylabel('Number of turnstile entries')
xt = plt.xticks(np.arange(7),['S','S','M','T','W','R','F'])

# %% [markdown]
# ###Function for rainbow weekly ridership curves

# %%
# let's make a function that does everything we just did to make this "rainbow line" plot
# try it out on a random boothremote
import random
br = random.sample(boothremotes.items(),1)[0]

# what station is that anyway?
# make the station key
station_key = mta.create_booth_remote_station_key('turnstile_key.csv')
#print station_key[br_id]

mta.plot_weeks(br,station_key[br[0]])

# %%
boothremotes.iteritems().next()
# Out:
# [datetime.datetime(2014, 5, 24, 0, 0), 836]

# %%
# make a function that does all that stuff up there and do it on a random station
import random
reload(mta)

#sta = ('R202','R042')
mta.plot_timeseries_and_weeklies(mta.get_a_random_boothremote(boothremotes),station_key)
#plot_timeseries_and_weeklies((sta,boothremotes[sta]))
#pprint(boothremotes[sta])

# %%
# let's take the rainbow plot and turn it into averages with error bars

# boothremotes weekly
br = mta.get_a_random_boothremote(boothremotes)
station_name = station_key[br[0]]
print br[0], station_name 

weekly = mta.reshape_flat_counts_to_weekly([c for d,c in br[1]])
print weekly

# numpy arrays are awesome! by using the axis parameter you can find the mean of all columns at once.
import numpy as np
print np.mean(weekly,0).astype(int)
print np.std(weekly,0).astype(int)
# Out:
# ('B004', 'R171') 7 AVE
# [[ 5055  4320  4733  9838 10301 10370 10231]
#  [ 6037  4852  9837 10191  9655  9727  9914]
#  [ 6037  4539  9260 10150 10252 10322  9626]
#  [ 5834  4479  9511  9926 10059  9846  9952]
#  [ 5953  4456  9567  9870 10013 10053  9733]
#  [ 5483  4413  8849  9085  9075  8542  3618]
#  [ 4384  3689  8690  9102  9370  9411  9223]
#  [ 5293  4000  8672  9026  9544  9433  9097]
#  [ 5119  4167  8862  9348  9468  9474  9059]
#  [ 4827  3800  8756  9255  9721  9374  8760]
#  [ 5085  3897  8649  8965  9299  9076  8698]
#  [ 4961  4013  8477  8672  8949  8984  8649]
#  [ 4946  3609  8369  8730  8813  8862  8353]
#  [ 4437  3893  8201  8638  8846  8679  7359]]
# [5246 4151 8602 9342 9526 9439 8733]
# [ 533  352 1167  529  484  556 1594]

# %%
#so let's make a plot of the means 
from scipy import stats
err = stats.sem(weekly)
#print err

f=plt.figure(figsize=(8,3))
plt.errorbar(np.arange(7),np.mean(weekly,0),yerr=err)
#plt.errorbar(np.arange(7),np.mean(weekly,0),yerr=np.std(weekly,0))
#a = plt.gca()
xl = plt.xlim([-1,7])
xt = plt.xticks(np.arange(8),['S','S','M','T','W','R','F',''])
tt = plt.title(station_name)

# %%
print weekly
# Out:
# [[ 836  684  815 2387 2403 2473 2445]
#  [ 958  724 2484 2473 2476 2260 2449]
#  [1033  771 2298 2474 2550 2517 2393]
#  [   6    0 2356 2494 2409 2424 2373]
#  [   6    0 2268 2410 2305 2357 2168]
#  [   7    0 2149 2255 2140 2055  688]
#  [ 449  284 2062 2254 2263 1860 2024]
#  [ 474  297 2117 2161 2192 2237 2129]
#  [ 566  396 2104 2230 2234 2235 2124]
#  [ 599  411 2084 2130 2309 2200 2031]
#  [ 544  409 2059 2170 2142 2126 2000]
#  [ 563  479 2015 2151 2047 2074 2048]
#  [   4    0 2035 2087 2078 2077 1955]
#  [ 684  509 2017 2102 2082 2113 1919]]

# %%
# and let's turn this into a function

def plot_avg_weeklies_with_err_bars(br=None):
    if not br: 
        br=mta.get_a_random_boothremote(boothremotes)

    weekly = mta.reshape_flat_counts_to_weekly([c for d,c in br[1]])
#    err = np.std(weekly,0)
    err = stats.sem(weekly)
    f=plt.figure(figsize=(8,3))
    plt.errorbar(np.arange(7),np.mean(weekly,0),yerr=err)
    xl = plt.xlim([-1,7])
    xt = plt.xticks(np.arange(8),['S','S','M','T','W','R','F',''])
    tt = plt.title(station_key[br[0]])
    return 

#test it
plot_avg_weeklies_with_err_bars()

# %%
# so there is more than one booth remote per station. Let's see what we can do about that

# we have the station key but it goes the wrong way. let's change it around so that we are indexing on the station name
from collections import defaultdict

station_dict = defaultdict(list)
for boothremote,station in station_key.items():
    station_dict[station].append(boothremote)
    
#pprint(dict(station_dict))

#let's get a random station
def get_a_random_station():
    station = random.sample(station_dict,1)[0]
    return station
print station, station_dict[station]


#'86 ST' is a good one with lots of booth remotes
# Out:
# BAY PKY-22 AVE [('D010', 'R394'), ('D011', 'R394')]

# %%
# and let's alter our function from above to plot all of the booth remotes for a station
def plot_all_brs_for_station(station=None):
    if not station: 
        station=get_a_random_station()
    f=plt.figure(figsize=(8,3))
    
    for boothremote in station_dict[station]:
        br = boothremotes[boothremote]
        weekly = mta.reshape_flat_counts_to_weekly([c for d,c in br])
        #print boothremote
        #print weekly
        plt.errorbar(np.arange(7),np.mean(weekly,0),yerr=err,label=boothremote)
        
    xl = plt.xlim([-1,7])
    xt = plt.xticks(np.arange(8),['S','S','M','T','W','R','F',''])
    tt = plt.title(station)
    plt.legend(bbox_to_anchor=(1.35,1))
    #lg = plt.figlegend(f,label=station_dict[station],loc=3)
    return 

#plot_all_brs_for_station()
plot_all_brs_for_station(station='ROCKAWAY BLVD')

# %%
stations = {}
for station,br_names in station_dict.items():
    total_ridership = 0
    daily_totals = np.array([0,0,0,0,0,0,0])
    for br_name in br_names: 
        br = boothremotes[br_name]
        weekly = mta.reshape_flat_counts_to_weekly([c for d,c in br])
        weekly_sums = np.sum(weekly,0)
        daily_totals = daily_totals+weekly_sums
        total_ridership += np.sum(weekly_sums)
    stations[station]={
    'daily_totals':daily_totals,
    'total_ridership':total_ridership}

# %%
total_ridership = []
for station,br_names in station_dict.items():
    total_ridership.append((sum([sum([c for d,c in boothremotes[br_name]]) for br_name in br_names]),station))
    
average_weekly_ridership = []
for station,br_names in station_dict.items()[:5]:
    rect= [[c for d,c in boothremotes[br_name]] for br_name in br_names]
    print len(br_names)
#    mean_rect = np.mean(rect)
    print rect#,mean_rect

#    a = [sum(reshape_flat_counts_to_weekly([c for d,c in boothremotes[br_name]]),1) for br_name in br_names]
#    average_weekly_ridership.append((sum(a)*1.0/len(a),station))
# Out:
# 1
# [[4696, 2405, 2485, 7419, 7592, 7656, 7397, 2878, 6929, 7593, 7494, 7575, 7316, 8747, 3195, 1892, 7156, 7724, 7626, 7803, 6842, 2596, 1655, 7843, 7749, 7764, 7766, 7277, 2851, 1764, 7636, 7792, 7758, 7724, 9723, 2543, 2353, 7626, 7692, 7572, 6588, 2610, 2476, 1879, 7346, 7627, 7698, 7703, 6987, 4381, 1579, 6569, 7376, 7769, 7886, 7446, 4898, 1926, 7612, 7832, 7699, 7760, 7405, 8123, 1600, 7451, 7756, 8074, 11671, 7361, 4735, 1750, 7568, 7646, 7793, 7583, 7257, 2941, 1803, 7470, 7378, 7364, 7733, 7026, 2833, 1846, 7164, 7528, 7505, 7243, 6896, 4547, 1895, 7033, 8409, 7064, 7057, 6293]]
# 1
# [[0, 0, 7952, 46963, 48371, 48539, 43994, 0, 0, 48659, 49278, 49109, 47474, 45130, 0, 0, 45797, 43060, 49197, 48724, 42959, 0, 0, 48285, 49876, 50298, 48629, 43919, 0, 0, 47871, 49655, 48889, 48758, 44351, 0, 0, 47476, 48878, 47240, 41268, 12027, 61, 0, 45711, 48746, 48295, 48411, 44350, 0, 0, 47107, 48347, 49716, 49465, 43833, 0, 0, 47706, 49583, 48778, 49003, 44102, 0, 0, 46993, 49848, 49645, 50560, 43602, 0, 0, 48181, 49360, 48895, 48702, 43448, 0, 0, 46383, 47252, 44455, 46853, 42412, 0, 0, 45080, 47260, 46737, 43471, 40254, 0, 0, 44220, 46420, 44955, 44413, 34970]]
# 2
# [[6204, 5118, 5909, 9682, 9924, 10089, 10325, 6721, 5316, 9856, 9664, 10056, 9245, 10300, 6851, 5193, 9018, 9897, 9888, 9992, 10097, 11406, 8264, 9767, 9868, 10217, 9859, 10262, 6793, 5244, 9454, 9602, 9628, 9984, 9875, 6692, 5424, 9193, 9418, 9448, 9224, 5472, 6485, 5224, 9028, 9317, 9501, 9610, 9794, 7475, 5298, 9169, 9583, 9961, 10174, 10228, 7109, 5544, 9409, 9533, 9681, 9753, 9837, 6736, 5428, 8817, 9372, 9353, 9207, 9490, 6247, 5094, 9245, 9407, 9446, 9730, 10066, 6859, 5474, 9053, 9191, 9125, 9416, 9476, 6275, 4947, 8822, 9063, 9115, 9138, 9256, 6153, 4979, 8646, 9030, 9187, 9122, 8926], []]
# 1
# [[794, 847, 891, 1610, 1682, 1607, 1616, 917, 774, 1666, 1378, 1583, 1192, 1525, 731, 717, 1530, 1580, 1705, 1659, 1502, 888, 784, 1591, 1534, 1581, 1529, 1550, 917, 757, 1530, 1513, 1450, 1534, 1331, 891, 782, 1298, 4750, 716, 693, 1326, 1369, 1352, 1366, 1297, 812, 815, 1285, 1278, 1290, 1380, 1304, 823, 763, 1337, 1357, 1398, 1362, 1279, 792, 703, 1334, 1314, 1355, 1380, 1285, 750, 737, 1313, 1315, 1330, 1397, 1273, 829, 752, 1332, 1288, 1309, 1281, 1197, 834, 670, 1249, 1342, 1337, 1266, 1243, 767, 700, 1318, 1360, 1391, 1391, 1285]]
# 2
# [[10510, 10163, 9947, 16621, 17539, 17517, 17039, 11670, 11121, 15682, 15667, 16044, 15592, 16190, 11687, 10801, 16266, 17540, 18197, 17636, 16536, 12182, 10135, 16949, 17754, 17944, 17423, 16749, 12409, 10411, 16791, 17832, 18417, 18176, 17234, 12191, 10349, 16828, 17034, 16848, 14977, 7141, 9569, 8774, 15619, 17054, 17176, 17415, 16079, 11537, 8914, 15972, 16925, 17089, 17317, 16198, 12265, 10858, 16874, 18474, 18157, 17898, 16321, 9598, 6825, 16061, 17626, 17385, 17728, 16309, 10387, 9326, 16347, 17590, 17318, 17192, 15591, 11920, 9853, 15736, 16289, 16250, 17171, 15529, 11762, 9461, 15516, 15992, 16488, 16090, 14625, 8581, 7154, 14644, 15944, 15980, 16197, 12100], [6760, 5761, 5380, 12331, 12906, 13206, 12831, 6990, 5823, 11434, 11904, 11612, 11450, 11485, 6595, 5828, 12093, 12886, 13303, 13265, 12855, 6732, 5246, 11803, 12552, 12868, 12800, 12240, 7391, 6027, 12164, 12910, 13628, 13482, 12376, 7442, 6004, 11838, 12644, 12716, 10729, 5486, 5700, 5162, 11459, 12020, 12520, 12652, 11772, 6815, 5397, 11931, 12787, 12601, 12744, 11640, 7030, 5718, 11889, 12627, 13514, 12619, 11885, 4893, 3438, 11239, 12959, 12958, 12793, 11809, 6412, 5635, 11674, 12515, 12833, 12589, 11525, 6688, 5476, 11667, 12517, 12563, 12631, 11297, 6843, 5266, 10985, 11797, 11650, 11660, 10597, 5250, 4044, 10595, 11494, 11786, 11435, 8322]]

# %%
pprint(list(reversed(sorted(total_ridership))))
# Out:
# [(14895794, '34 ST-PENN STA'),
#  (12393484, '42 ST-GRD CNTRL'),
#  (10576031, '34 ST-HERALD SQ'),
#  (9505793, '14 ST-UNION SQ'),
#  (9232102, '42 ST-TIMES SQ'),
#  (9196025, '86 ST'),
#  (9002089, '42 ST-PA BUS TE'),
#  (7144663, '125 ST'),
#  (6374229, 'CANAL ST'),
#  (6004690, '59 ST-COLUMBUS'),
#  (5591377, '23 ST'),
#  (5361426, '59 ST'),
#  (5325201, 'CHAMBERS ST'),
#  (5247847, 'MAIN ST'),
#  (4746534, '47-50 ST-ROCK'),
#  (4372329, '72 ST'),
#  (4347372, '50 ST'),
#  (4293220, 'ROOSEVELT AVE'),
#  (4234437, 'FULTON ST'),
#  (4229694, 'WALL ST'),
#  (4040967, '96 ST'),
#  (3759292, '14 ST'),
#  (3713293, 'W 4 ST-WASH SQ'),
#  (3526313, 'LEXINGTON-53 ST'),
#  (3468681, 'JAMAICA CENTER'),
#  (3445893, '77 ST'),
#  (3419230, '42 ST-BRYANT PK'),
#  (3376030, '8 AVE'),
#  (3217145, 'BOWLING GREEN'),
#  (3206096, '145 ST'),
#  (3200209, 'PATH WTC'),
#  (3124033, 'CHURCH AVE'),
#  (3056316, 'JAY ST-METROTEC'),
#  (3044597, 'BOROUGH HALL/CT'),
#  (2994086, '116 ST'),
#  (2897178, '28 ST'),
#  (2859115, '103 ST'),
#  (2837061, 'GRAND ST'),
#  (2805907, 'BEDFORD AVE'),
#  (2774201, '161 ST-YANKEE'),
#  (2632515, 'MYRTLE AVE'),
#  (2609943, '33 ST'),
#  (2558381, 'LEXINGTON AVE'),
#  (2550686, '68ST-HUNTER COL'),
#  (2498939, 'SUTPHIN BLVD'),
#  (2444882, '57 ST-7 AVE'),
#  (2379844, 'DEKALB AVE'),
#  (2324768, 'FOREST HILLS-71'),
#  (2311646, '49 ST-7 AVE'),
#  (2292821, 'WOODHAVEN BLVD'),
#  (2286889, 'KINGS HIGHWAY'),
#  (2254008, '23 ST-6 AVE'),
#  (2250444, 'CROWN HTS-UTICA'),
#  (2234627, 'UNION TPK-KEW G'),
#  (2200907, 'SPRING ST'),
#  (2170586, 'BROADWAY/LAFAY'),
#  (2131051, '1 AVE'),
#  (2122790, 'FORDHAM ROAD'),
#  (2106007, 'THIRTY THIRD ST'),
#  (2102562, '168 ST-BROADWAY'),
#  (2054230, 'BROOKLYN BRIDGE'),
#  (2013165, 'STILLWELL AVE'),
#  (2011659, '149 ST-3 AVE'),
#  (1992592, '79 ST'),
#  (1981768, '5 AVE-53 ST'),
#  (1896833, '51 ST'),
#  (1890846, '23 ST-5 AVE'),
#  (1885028, 'JUNCTION BLVD'),
#  (1884303, 'ATLANTIC AVE'),
#  (1851783, 'FRANKLIN AVE'),
#  (1845550, 'JAMAICA-179 ST'),
#  (1841082, '181 ST'),
#  (1840656, 'NOSTRAND AVE'),
#  (1820256, '66 ST-LINCOLN'),
#  (1766038, '135 ST'),
#  (1732439, 'JOURNAL SQUARE'),
#  (1718390, '103 ST-CORONA'),
#  (1692063, '167 ST'),
#  (1654834, '5 AVE-59 ST'),
#  (1623384, 'FLATBUSH AVE'),
#  (1612384, 'PAVONIA/NEWPORT'),
#  (1554129, 'GRAND AV-NEWTON'),
#  (1541994, '14 ST-6 AVE'),
#  (1534885, 'NEWKIRK AVE'),
#  (1493326, '2 AVE'),
#  (1486544, 'ASTOR PLACE'),
#  (1472292, 'KINGSBRIDGE RD'),
#  (1451488, '90 ST-ELMHURST'),
#  (1441005, '61 ST/WOODSIDE'),
#  (1434571, 'DITMARS BL-31 S'),
#  (1429883, 'E 177 ST-PARKCH'),
#  (1421672, '36 ST'),
#  (1415199, "PRINCE ST-B'WAY"),
#  (1407232, "8 ST-B'WAY NYU"),
#  (1405405, 'FT HAMILTON PKY'),
#  (1399254, '7 AVE-53 ST'),
#  (1398315, 'GROVE STREET'),
#  (1385474, '82 ST-JACKSON H'),
#  (1374430, 'CHRISTOPHER ST'),
#  (1371389, '18 AVE'),
#  (1370045, '170 ST'),
#  (1332365, 'UTICA AVE'),
#  (1306242, 'STEINWAY ST'),
#  (1300965, '81 ST-MUSEUM'),
#  (1281863, 'BLEECKER ST'),
#  (1281504, 'DELANCEY ST'),
#  (1274022, 'GRAND-30 AVE'),
#  (1263502, 'BERGEN ST'),
#  (1263400, 'CITY / BUS'),
#  (1246962, '46 ST-BLISS ST'),
#  (1243755, 'COURT SQ'),
#  (1219077, 'METROPOLITAN AV'),
#  (1214122, 'HOUSTON ST'),
#  (1212074, '57 ST'),
#  (1197568, 'RECTOR ST'),
#  (1186620, 'HALSEY ST'),
#  (1177189, '111 ST'),
#  (1176130, 'ELMHURST AVE'),
#  (1171747, 'BROADWAY-31 ST'),
#  (1156083, 'EAST BROADWAY'),
#  (1150146, 'VERNON/JACKSON'),
#  (1147077, 'SHEEPSHEAD BAY'),
#  (1138663, '149 ST-GR CONC'),
#  (1136331, 'WORLD TRADE CTR'),
#  (1135133, 'NEWARK BM BW'),
#  (1122921, 'ROCKAWAY PKY'),
#  (1119836, 'AVE U'),
#  (1112407, 'BRIGHTON BEACH'),
#  (1105347, '137 ST-CITY COL'),
#  (1099072, '116 ST-COLUMBIA'),
#  (1098874, 'GUN HILL ROAD'),
#  (1096127, '110 ST-CATHEDRL'),
#  (1071413, '175 ST'),
#  (1070386, 'HOYT ST-ASTORIA'),
#  (1062094, 'PELHAM PARKWAY'),
#  (1061120, 'PROSPECT AVE'),
#  (1056007, 'EXCHANGE PLACE'),
#  (1035384, 'SUTTER AVE'),
#  (1034842, 'ST. GEORGE'),
#  (1027059, '110 ST'),
#  (1026106, 'BEDFORD PARK BL'),
#  (1021082, 'QUEENSBORO PLZ'),
#  (1014235, '7 AV-PARK SLOPE'),
#  (1000447, '28 ST-BROADWAY'),
#  (996192, 'PACIFIC ST'),
#  (995559, 'MARCY AVE'),
#  (981883, 'NEW LOTS AVE'),
#  (967773, 'FLUSHING AVE'),
#  (955683, '5 AVE-BRYANT PK'),
#  (954827, 'NEVINS ST'),
#  (940523, 'CLINTON-WASH AV'),
#  (937522, 'LORIMER ST'),
#  (919394, '157 ST'),
#  (908899, 'CARROLL ST'),
#  (903443, '40 ST-LOWERY ST'),
#  (897313, 'BURNSIDE AVE'),
#  (893664, 'GRAHAM AVE'),
#  (891646, 'ROCKAWAY AVE'),
#  (882763, 'EUCLID AVE'),
#  (877822, '33 ST/RAWSON ST'),
#  (866201, '14TH STREET'),
#  (858228, 'BROADWAY-ENY'),
#  (857328, 'PROSPECT PARK'),
#  (854035, 'HUNTS POINT AVE'),
#  (845746, 'THIRTY ST'),
#  (835043, 'TREMONT AVE'),
#  (827314, '110 ST-CPN'),
#  (802016, 'HOYT/SCHERMER'),
#  (800014, '46 ST'),
#  (789833, 'VAN SICLEN AVE'),
#  (787777, 'QUEENS PLAZA'),
#  (784764, 'HIGH ST'),
#  (775743, 'ESSEX ST'),
#  (772425, 'SIMPSON ST'),
#  (770597, '7 AVE'),
#  (769738, 'MOSHOLU PARKWAY'),
#  (769625, 'INWOOD-207 ST'),
#  (769476, '231 ST'),
#  (759026, '20 AVE'),
#  (747585, 'YORK ST'),
#  (740385, '169 ST'),
#  (736772, '9 ST'),
#  (731393, 'NASSAU AV'),
#  (729194, '67 AVE'),
#  (728016, 'NORWOOD-205 ST'),
#  (721701, 'METS-WILLETS PT'),
#  (702348, '21 ST'),
#  (689234, '191 ST'),
#  (687124, 'PELHAM BAY PARK'),
#  (684633, 'ROCKAWAY BLVD'),
#  (679187, 'E 180 ST'),
#  (677376, 'JFK JAMAICA CT1'),
#  (676087, 'MORGAN AVE'),
#  (673878, 'WOODLAWN ROAD'),
#  (673431, 'E TREMONT AVE'),
#  (666923, '138 ST-3 AVE'),
#  (659169, 'BAY RIDGE AVE'),
#  (659097, '18 ST'),
#  (657761, 'JEFFERSON ST'),
#  (656840, 'TWENTY THIRD ST'),
#  (651349, 'BEDFORD/NOSTRAN'),
#  (647462, 'BAY PARKWAY'),
#  (643928, 'CATHEDRL-110 ST'),
#  (643866, 'GRAND ARMY PLAZ'),
#  (643347, 'WASHINGTON-36 A'),
#  (637614, 'COURT SQ-23 ST'),
#  (636883, '3 AVE'),
#  (635618, 'BAY PKY-22 AVE'),
#  (629521, 'DYCKMAN ST'),
#  (625802, 'NORTHERN BLVD'),
#  (624480, '53 ST'),
#  (612204, '242 ST'),
#  (611088, 'MONTROSE AVE'),
#  (610278, 'LEFFERTS BLVD'),
#  (606552, 'HARRISON'),
#  (603312, '174 ST'),
#  (601143, '45 ST'),
#  (595963, 'WHITEHALL ST'),
#  (594044, 'LACKAWANNA'),
#  (590890, '52 ST-LINCOLN'),
#  (580831, 'HOYT ST'),
#  (578731, 'WINTHROP ST'),
#  (576810, '155 ST'),
#  (572154, 'MORRISON AVE'),
#  (569731, '207 ST'),
#  (566870, 'CLARK ST'),
#  (559240, 'WESTCHESTER SQ'),
#  (554407, '6 AVE'),
#  (553575, 'ELDER AVE'),
#  (552743, 'GRANT AVE'),
#  (552275, '15 ST-PROSPECT'),
#  (551514, 'CASTLE HILL AVE'),
#  (541304, 'BROOK AVE'),
#  (538863, 'PARSONS BLVD'),
#  (538262, 'DYCKMAN-200 ST'),
#  (528180, '183 ST'),
#  (526030, '9 AVE'),
#  (523298, 'GATES AVE'),
#  (516281, 'UNION ST'),
#  (509193, 'KINGSTON-THROOP'),
#  (499752, 'ROOSEVELT IS'),
#  (495462, 'BAY RIDGE-95 ST'),
#  (495044, 'PARK PLACE'),
#  (494855, 'CORTELYOU ROAD'),
#  (492543, 'MARBLE HILL-225'),
#  (491879, '9TH STREET'),
#  (490079, 'MT EDEN AVE'),
#  (489438, '176 ST'),
#  (485821, 'ALLERTON AVE'),
#  (483183, 'HUNTERS PT AVE'),
#  (482449, 'AVE J'),
#  (481374, '233 ST'),
#  (480481, 'RALPH AVE'),
#  (475043, 'SARATOGA AVE'),
#  (466265, '174-175 ST'),
#  (465933, 'WAKEFIELD-241'),
#  (465638, 'FRANKLIN ST'),
#  (465629, 'BROAD ST'),
#  (461646, 'PARKSIDE AVE'),
#  (456284, 'GREENPOINT AVE'),
#  (455060, 'STERLING ST'),
#  (449774, 'NEW UTRECHT AVE'),
#  (448513, 'PENNSYLVANIA AV'),
#  (448423, '69 ST-FISK AVE'),
#  (444592, 'FRESH POND ROAD'),
#  (444494, 'MYRTLE-WILLOUGH'),
#  (438213, 'LAFAYETTE AVE'),
#  (435804, 'EASTERN PKWY'),
#  (426116, 'JAMAICA-VAN WYC'),
#  (425515, 'JACKSON AVE'),
#  (420671, 'AVE M'),
#  (419806, 'SMITH-9 ST'),
#  (418808, 'CRESCENT ST'),
#  (416977, 'FAR ROCKAWAY'),
#  (411720, 'RIT-MANHATTAN'),
#  (410914, 'RIT-ROOSEVELT'),
#  (408188, '182-183 ST'),
#  (405879, 'KOSCIUSZKO ST'),
#  (404240, '71 ST'),
#  (398316, 'E 149 ST'),
#  (396997, 'HUDSON-80 ST'),
#  (395697, '25 AVE'),
#  (392052, 'KINGSTON AVE'),
#  (379893, 'FREEMAN ST'),
#  (376771, 'DYRE AVE'),
#  (374416, 'VAN WYCK BLVD'),
#  (374208, '225 ST'),
#  (373894, 'CLASSON AVE'),
#  (371329, 'NEWARK HW BMEBE'),
#  (368413, 'WILSON AVE'),
#  (366695, 'DITMAS AVE'),
#  (365884, '163 ST-AMSTERDM'),
#  (360814, 'CORTLANDT ST'),
#  (360200, '4 AVE'),
#  (358549, 'NEWARK C'),
#  (352187, 'ST LAWRENCE AVE'),
#  (351371, 'BEVERLY ROAD'),
#  (351122, '190 ST'),
#  (340650, 'NECK ROAD'),
#  (337893, '25 ST'),
#  (330413, 'CYPRESS AVE'),
#  (326578, '63 DR-REGO PARK'),
#  (324654, '238 ST'),
#  (323481, 'FOREST AVE'),
#  (322698, '74 ST-BROADWAY'),
#  (321817, 'EAST 105 ST'),
#  (320065, 'FOREST PARKWAY'),
#  (316019, 'BEEBE-39 AVE'),
#  (314684, 'NEREID AVE'),
#  (313241, '65 ST'),
#  (307225, 'BURKE AVE'),
#  (305835, '148 ST-LENOX'),
#  (305103, 'LONGWOOD AVE'),
#  (302081, 'NORWOOD AVE'),
#  (301075, '75 AVE'),
#  (298949, '219 ST'),
#  (298766, 'BAYCHESTER AVE'),
#  (294948, 'ELDERTS LANE'),
#  (294215, 'CLEVELAND ST'),
#  (294179, 'PRESIDENT ST'),
#  (294094, 'KNICKERBOCKER'),
#  (291590, 'BOWERY'),
#  (289597, 'W 8 ST-AQUARIUM'),
#  (281627, 'OCEAN PARKWAY'),
#  (280258, '138 ST-GR CONC'),
#  (273419, 'SHEPHERD AVE'),
#  (271229, 'INTERVALE-163'),
#  (270692, 'BROADWAY'),
#  (269887, 'AVE N'),
#  (264554, 'LIVONIA AVE'),
#  (258110, "MURRAY ST-B'WAY"),
#  (255959, 'CHAUNCEY ST'),
#  (254403, 'CENTRAL AVE'),
#  (249115, 'JFK HOWARD BCH'),
#  (243562, 'BRONX PARK EAST'),
#  (238758, 'AVE X'),
#  (236443, 'BAY 50 ST'),
#  (235362, 'BEVERLEY ROAD'),
#  (232694, 'HEWES ST'),
#  (229199, 'MIDDLETOWN ROAD'),
#  (227256, 'AVE P'),
#  (226632, 'AVE H'),
#  (218152, '104 ST'),
#  (217914, 'ALABAMA AVE'),
#  (217026, 'BEACH 67 ST'),
#  (216853, 'BEACH 60 ST'),
#  (209987, 'LIBERTY AVE'),
#  (209583, 'HOWARD BCH-JFK'),
#  (206856, '121 ST'),
#  (202830, 'GREENWOOD-111'),
#  (195965, 'SENECA AVE'),
#  (191658, 'JUNIUS ST'),
#  (183189, 'AQUEDUCT TRACK'),
#  (181112, 'BOYD-88 ST'),
#  (173006, '215 ST'),
#  (169508, 'AVE I'),
#  (163718, 'MORRIS PARK'),
#  (157574, '55 ST'),
#  (150592, 'WHITLOCK AVE'),
#  (148404, 'BUSHWICK AVE'),
#  (138963, 'BEACH 25 ST'),
#  (136246, 'BOTANIC GARDEN'),
#  (132672, 'NEPTUNE AVE'),
#  (129966, 'BUHRE AVE'),
#  (123858, 'OXFORD-104 ST'),
#  (118942, 'CYPRESS HILLS'),
#  (118737, '22 AVE-BAY PKY'),
#  (108990, 'BEACH 90 ST'),
#  (105258, 'AQUEDUCT-N CNDT'),
#  (102251, 'ZEREGA AVE'),
#  (97879, 'ROCKAWAY PK 116'),
#  (87428, 'NEWARK HM HE'),
#  (85286, 'BEACH 98 ST'),
#  (84762, 'VAN ALSTON-21ST'),
#  (78900, 'BEACH 36 ST'),
#  (74724, 'E 143 ST'),
#  (62817, 'TOMPKINSVILLE'),
#  (54998, 'BEACH 44 ST'),
#  (54623, 'ORCHARD BEACH'),
#  (36603, 'PATH WTC 2'),
#  (29954, 'BEACH 105 ST'),
#  (24564, 'BROAD CHANNEL'),
#  (0, 'WEST COUNTY CTR'),
#  (0, 'SOUTH FERRY'),
#  (0, 'NYC & CO - 7 AV'),
#  (0, 'METROCARD VAN-3'),
#  (0, 'METROCARD VAN-2'),
#  (0, 'METROCARD VAN-1'),
#  (0, 'METROCARD BUS 2'),
#  (0, 'METROCARD BUS 1'),
#  (0, 'LIB-HEMPSTEAD'),
#  (0, 'LGA AIRPORT CTB'),
#  (0, 'JFK JAMAICA CT2'),
#  (0, 'ELTINGVILLE PK'),
#  (0, '2 BDWY CUST SRV')]

# %%
station_totals = [a for (a,b) in total_ridership]
#print station_totals
h = plt.hist(station_totals,50)
